# %% [markdown]
# <a href="https://colab.research.google.com/github/rebeccalizaverghese/Python-Revision/blob/main/06_02_Python_Revision_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Supermarket_sales.csv")

# %%
df #python automatically adds index starting from '0'
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
df.head() # printfirst five rows
# Out:
#    No    InvoiceID Branch       City Customertype  Gender  \
# 0   1  750-67-8428      A     Yangon       Member  Female
# 1   2  226-31-3081      C  Naypyitaw       Normal  Female
# 2   3  631-41-3108      A     Yangon       Normal    Male
# 3   4  123-19-1176      A     Yangon       Member    Male
# 4   5  373-73-7910      A     Yangon       Normal    Male
#
#               Productline  Unitprice  Quantity      Tax     Total       Date  \
# 0       Health and beauty      74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories      15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle      46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty      58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel      86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross_margin_percentage  gross_iincome  Rating
# ...

# %%
df.tail() #print last five rows
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#              Productline  Unitprice  Quantity      Tax      Total       Date  \
# 995    Health and beauty      40.35         1   2.0175    42.3675  1/29/2019
# 996   Home and lifestyle      97.38        10  48.6900  1022.4900   3/2/2019
# 997   Food and beverages      31.84         1   1.5920    33.4320   2/9/2019
# 998   Home and lifestyle      65.82         1   3.2910    69.1110  2/22/2019
# 999  Fashion accessories      88.34         7  30.9190   649.2990  2/18/2019
#
#       Time  Payment    cogs  gross_margin_percentage  gross_iincome  Rating
# ...

# %%
df.InvoiceID
# Out:
# 0      750-67-8428
# 1      226-31-3081
# 2      631-41-3108
# 3      123-19-1176
# 4      373-73-7910
#           ...
# 995    233-67-5758
# 996    303-96-2227
# 997    727-02-1313
# 998    347-56-2442
# 999    849-09-3807
# Name: InvoiceID, Length: 1000, dtype: object

# %%
df.InvoiceID[1]
# Out:
# '226-31-3081'

# %%
df.City[49]
# Out:
# 'Naypyitaw'

# %%
df.Branch[99] #to find branch of 100th value. index99
# Out:
# 'B'

# %%
 df.Customertype[999]
# Out:
# 'Member'

# %%
df.shape #to find no. of rows n columns - 1000rows n 18columns
# Out:
# (1000, 18)

# %%
if df.City[18]=="Yangon":
  print (df.Branch[18])
# Out:
# A

# %%
if df.Customertype[100]=="Member":
  print (df.InvoiceID[100])
# Out:
# 163-56-7055

# %%
#Sales Data.pdf
#Q1
print(df.Unitprice.max())
print(df.Unitprice.min())
print(df.Unitprice.mean())
# Out:
# 99.96
# 10.08
# 55.67213

# %%
#Q2
print(df.Quantity.max())
print(df.Quantity.min())
print(df.Quantity.mean())
# Out:
# 10
# 1
# 5.51

# %%
#Q3 => filtering =>df.loc (location)
print(df.Quantity.loc[df['Productline']=="Health and beauty"].max())
print(df.Quantity.loc[df['Productline']=="Health and beauty"].min())
print(df.Quantity.loc[df['Productline']=="Health and beauty"].mean())
# Out:
# 10
# 1
# 5.618421052631579

# %%
#Q4
print(df.Unitprice.loc[df['Productline']=="Health and beauty"].max())
print(df.Unitprice.loc[df['Productline']=="Health and beauty"].min())
print(df.Unitprice.loc[df['Productline']=="Health and beauty"].mean())
# Out:
# 99.96
# 10.08
# 54.85447368421053

# %%
#Q5
print(df.Quantity.loc[df['Productline']=="Electronic accessories"].max())
print(df.Quantity.loc[df['Productline']=="Electronic accessories"].min())
print(df.Quantity.loc[df['Productline']=="Electronic accessories"].mean())
# Out:
# 10
# 1
# 5.711764705882353

# %%
#Q6 - skipped
#Q7
df.loc[(df['Gender']=="Male") & (df['Productline']=="Health and beauty")]
# Out:
#       No    InvoiceID Branch       City Customertype Gender  \
# 3      4  123-19-1176      A     Yangon       Member   Male
# 21    22  371-85-5789      B   Mandalay       Normal   Male
# 29    30  848-62-7243      A     Yangon       Normal   Male
# 33    34  595-11-5460      A     Yangon       Normal   Male
# 44    45  617-15-4209      C  Naypyitaw       Member   Male
# ..   ...          ...    ...        ...          ...    ...
# 981  982  809-46-1866      A     Yangon       Normal   Male
# 983  984  148-41-7930      C  Naypyitaw       Normal   Male
# 987  988  552-44-5977      B   Mandalay       Member   Male
# 989  990  430-53-4718      B   Mandalay       Member   Male
# 995  996  233-67-5758      C  Naypyitaw       Normal   Male
#
#            Productline  Unitprice  Quantity      Tax     Total       Date  \
# 3    Health and beauty      58.22         8  23.2880  489.0480  1/27/2019
# 21   Health and beauty      87.98         3  13.1970  277.1370   3/5/2019
# ...

# %%
#Q8
df.loc[(df['Gender']=="Female") & (df['Productline']=="Fashion accessories")]
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 10     11  351-62-0822      B   Mandalay       Member  Female
# 27     28  189-17-4241      A     Yangon       Normal  Female
# 49     50  574-22-5561      C  Naypyitaw       Member  Female
# 52     53  616-24-2851      B   Mandalay       Member  Female
# 67     68  109-28-2512      B   Mandalay       Member  Female
# ..    ...          ...    ...        ...          ...     ...
# 931   932  756-93-1854      C  Naypyitaw       Member  Female
# 955   956  846-10-0341      A     Yangon       Normal  Female
# 962   963  593-08-5916      A     Yangon       Normal  Female
# 985   986  374-38-5555      B   Mandalay       Normal  Female
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#              Productline  Unitprice  Quantity      Tax     Total       Date  \
# 10   Fashion accessories      14.48         4   2.8960   60.8160   2/6/2019
# ...

# %%
#Q9
df.loc[(df['Gender']=="Female") & ((df['Productline']=="Fashion accessories")|(df['Productline']=="Sports and travel"))] #|=>'or'
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 10     11  351-62-0822      B   Mandalay       Member  Female
# 15     16  299-46-1805      B   Mandalay       Member  Female
# 27     28  189-17-4241      A     Yangon       Normal  Female
# 35     36  232-16-2483      C  Naypyitaw       Member  Female
# 42     43  354-25-5821      B   Mandalay       Member  Female
# ..    ...          ...    ...        ...          ...     ...
# 962   963  593-08-5916      A     Yangon       Normal  Female
# 982   983  139-32-4183      A     Yangon       Member  Female
# 985   986  374-38-5555      B   Mandalay       Normal  Female
# 991   992  602-16-6955      B   Mandalay       Normal  Female
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#              Productline  Unitprice  Quantity      Tax     Total       Date  \
# 10   Fashion accessories      14.48         4   2.8960   60.8160   2/6/2019
# ...

# %%
#Q10
import pandas as pd
import matplotlib.pyplot as plt
x=df["Quantity"]
y=df["Tax"]
plt.plot(x,y)
plt.show()
